# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
import datetime as dt
import random
from scipy import stats
from citipy import citipy
from scipy.stats import linregress
from pprint import pprint

#from config import api_key

# Import API key
from api_keys import weather_api_key

# %%
# Save config information
random_points = 50
rnd_lng = np.random.uniform(-180,180,[random_points])
rnd_lat = np.random.uniform(-90,90,[random_points])

random_latlng = pd.DataFrame({"Latitude": rnd_lat,
                             "Longitude": rnd_lng})

random_latlng.head()
# Out:
#     Latitude   Longitude
# 0 -27.651269  160.870677
# 1   5.471643  -32.681282
# 2 -73.966429  145.720336
# 3  49.766288   14.704157
# 4 -10.873917  130.398209

# %%
citipy.nearest_city(66.350533, 56.074969)

# %%
city = []
country = []

for x in range (0, random_points):
    lat = random_latlng.iloc[x]["Latitude"]
    lng = random_latlng.iloc[x]["Longitude"]

    random_city = citipy.nearest_city(lat, lng).city_name
    random_city_country = citipy.nearest_city(lat, lng).country_code
    city.append(random_city)
    country.append(random_city_country)
    
    random_city

# %%
random_latlng["City"] = city
random_latlng["Country Code"] = country

random_latlng
# Out:
#      Latitude   Longitude                  City Country Code
# 0  -27.651269  160.870677             byron bay           au
# 1    5.471643  -32.681282                jardim           br
# 2  -73.966429  145.720336                hobart           au
# 3   49.766288   14.704157               benesov           cz
# 4  -10.873917  130.398209                 nguiu           au
# 5   -5.154590   -4.836885                 tabou           ci
# 6    5.640586   53.148949                   eyl           so
# 7  -13.261361   -2.280805             jamestown           sh
# 8  -78.243861   65.917442             taolanaro           mg
# 9  -63.109274   67.094888             taolanaro           mg
# 10  34.865259  -24.832672  vila franca do campo           pt
# 11 -54.334893 -162.892463                avarua           ck
# 12  43.931209 -177.279285           provideniya           ru
# 13 -42.547205    6.744780             cape town           za
# 14  88.719664  136.398613           nizhneyansk           ru
# 15  66.253936  -39.429826              tasiilaq           gl
# 16  49.072405   34.560970           tsarychanka           ua
# 17  40.303526  -36.835659        ribeira grande           pt
# 18  12.062584  -96.987124              pochutla           mx
# 19  58.891871  -84.981568          attawapiskat           ca
# 20  54.202745 -174.044518           provideniya           ru
# 21 -70.421666   -1.846222              hermanus           za
# 22 -39.515662   74.193051             mahebourg           mu
# 23 -29.599931  179.443293               russell           nz
# 24  83.537062   62.710688               amderma           ru
# 25  67.491913   27.732325             kemijarvi           fi
# 26 -51.342993   65.830605        saint-philippe           re
# 27 -46.687817   50.876730             taolanaro           mg
# 28  26.293573  -56.315234            codrington           ag
# 29 -23.335089   61.249582       bambous virieux           mu
# 30  49.689926 -104.070980               weyburn           ca
# 31  48.928049  -45.583934                torbay           ca
# 32  82.104425   27.861745                mehamn           no
# 33  64.848754  -54.661935             maniitsoq           gl
# 34  83.545889 -143.079604           tuktoyaktuk           ca
# 35  64.036057  -74.761755               iqaluit           ca
# 36   6.315115 -177.163523               vaitupu           wf
# 37  81.035476   89.717588               talnakh           ru
# 38  55.255028 -110.067989          grand centre           ca
# 39  -0.514632 -140.916666                atuona           pf
# 40  51.482532  148.404294                vostok           ru
# 41 -58.646774   25.469117          kruisfontein           za
# 42   4.161418  158.133565             namatanai           pg
# 43  80.867335  -88.166399               qaanaaq           gl
# 44 -13.475242  -55.263734            diamantino           br
# 45 -46.397264  -93.709932                castro           cl
# 46 -60.454609 -149.733841               mataura           pf
# 47  50.908370  -21.936661                dingle           ie
# 48 -29.765223  121.159358             esperance           au
# 49 -20.948059    2.859429             jamestown           sh

# %% [markdown]
# ## Generate Cities List

# %%
cities_list = []

cities_list.append(random_latlng["City"])

cities_list
# Out:
# [0                byron bay
#  1                   jardim
#  2                   hobart
#  3                  benesov
#  4                    nguiu
#  5                    tabou
#  6                      eyl
#  7                jamestown
#  8                taolanaro
#  9                taolanaro
#  10    vila franca do campo
#  11                  avarua
#  12             provideniya
#  13               cape town
#  14             nizhneyansk
#  15                tasiilaq
#  16             tsarychanka
#  17          ribeira grande
#  18                pochutla
#  19            attawapiskat
#  20             provideniya
#  21                hermanus
#  22               mahebourg
#  23                 russell
#  24                 amderma
#  25               kemijarvi
#  26          saint-philippe
#  27               taolanaro
#  28              codrington
#  29         bambous virieux
#  30                 weyburn
#  31                  torbay
#  32                  mehamn
#  33               maniitsoq
#  34             tuktoyaktuk
#  35                 iqaluit
#  36                 vaitupu
#  37                 talnakh
#  38            grand centre
#  39                  atuona
#  40                  vostok
#  41            kruisfontein
#  42               namatanai
#  43                 qaanaaq
#  44              diamantino
#  45                  castro
#  46                 mataura
#  47                  dingle
#  48               esperance
#  49               jamestown
#  Name: City, dtype: object]

# %%
cities_clean = random_latlng
cities_clean
# Out:
#      Latitude   Longitude                  City Country Code
# 0  -27.651269  160.870677             byron bay           au
# 1    5.471643  -32.681282                jardim           br
# 2  -73.966429  145.720336                hobart           au
# 3   49.766288   14.704157               benesov           cz
# 4  -10.873917  130.398209                 nguiu           au
# 5   -5.154590   -4.836885                 tabou           ci
# 6    5.640586   53.148949                   eyl           so
# 7  -13.261361   -2.280805             jamestown           sh
# 8  -78.243861   65.917442             taolanaro           mg
# 9  -63.109274   67.094888             taolanaro           mg
# 10  34.865259  -24.832672  vila franca do campo           pt
# 11 -54.334893 -162.892463                avarua           ck
# 12  43.931209 -177.279285           provideniya           ru
# 13 -42.547205    6.744780             cape town           za
# 14  88.719664  136.398613           nizhneyansk           ru
# 15  66.253936  -39.429826              tasiilaq           gl
# 16  49.072405   34.560970           tsarychanka           ua
# 17  40.303526  -36.835659        ribeira grande           pt
# 18  12.062584  -96.987124              pochutla           mx
# 19  58.891871  -84.981568          attawapiskat           ca
# 20  54.202745 -174.044518           provideniya           ru
# 21 -70.421666   -1.846222              hermanus           za
# 22 -39.515662   74.193051             mahebourg           mu
# 23 -29.599931  179.443293               russell           nz
# 24  83.537062   62.710688               amderma           ru
# 25  67.491913   27.732325             kemijarvi           fi
# 26 -51.342993   65.830605        saint-philippe           re
# 27 -46.687817   50.876730             taolanaro           mg
# 28  26.293573  -56.315234            codrington           ag
# 29 -23.335089   61.249582       bambous virieux           mu
# 30  49.689926 -104.070980               weyburn           ca
# 31  48.928049  -45.583934                torbay           ca
# 32  82.104425   27.861745                mehamn           no
# 33  64.848754  -54.661935             maniitsoq           gl
# 34  83.545889 -143.079604           tuktoyaktuk           ca
# 35  64.036057  -74.761755               iqaluit           ca
# 36   6.315115 -177.163523               vaitupu           wf
# 37  81.035476   89.717588               talnakh           ru
# 38  55.255028 -110.067989          grand centre           ca
# 39  -0.514632 -140.916666                atuona           pf
# 40  51.482532  148.404294                vostok           ru
# 41 -58.646774   25.469117          kruisfontein           za
# 42   4.161418  158.133565             namatanai           pg
# 43  80.867335  -88.166399               qaanaaq           gl
# 44 -13.475242  -55.263734            diamantino           br
# 45 -46.397264  -93.709932                castro           cl
# 46 -60.454609 -149.733841               mataura           pf
# 47  50.908370  -21.936661                dingle           ie
# 48 -29.765223  121.159358             esperance           au
# 49 -20.948059    2.859429             jamestown           sh

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
api_keys = weather_api_key

# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# set up lists to hold reponse info
lat = []
lng = []
temp = []
temp_min = []
temp_max = []
wind_speed = []
humidity = []
cloudiness = []
city_id = []

    
# Loop through the list of cities and perform a request for data on each
for index, row in cities_clean.iterrows():
    CityStatus = row["City"]
    CountryStatus = row["Country Code"]
    query_url = f"{url}&appid={weather_api_key}&units={units}&q={CityStatus}"
    query_url = f"{url}q={CityStatus},{CountryStatus}&units={units}&appid={weather_api_key}"
    #http://api.openweathermap.org/data/2.5/weather?appid=c5779a215d57f746e1592fcc7f7b17b7&units=metric&q=paris
    response = requests.get(query_url).json()
    
    try:
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        temp.append(response["main"]["temp"])
        temp_max.append(response["main"]["temp_max"])
        temp_min.append(response["main"]["temp_min"])
        wind_speed.append(response["wind"]["speed"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])

        city_id.append(response["id"])
        #city_status_id = responnse["id"]
        print(f"Processeing Record | {CityStatus}, city ID: {city_id[index]}")
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        temp.append(np.nan)
        temp_max.append(np.nan)
        temp_min.append(np.nan)
        wind_speed.append(np.nan)
        humidity.append(np.nan)
        cloudiness.append(np.nan)

        city_id.append(np.nan)
        print(f"City not found. Skipping {CityStatus}")

#update latitude and longitude to actually match the city
cities_clean["Latitude"] = lat
cities_clean["Longitude"] = lng
cities_clean["Temp"] = temp
cities_clean["Temp Max"] = temp_max
cities_clean["Temp Min"] = temp_min
cities_clean["City ID"] = city_id
cities_clean["Wind Speed"] = wind_speed
cities_clean["Humidity"] = humidity
cities_clean["Cloudiness"] = cloudiness

#set date for when this finished running
date = dt.datetime.today().strftime("%m/%d/%Y")
cities_clean["Date"] = date
# Out:
# Processeing Record | byron bay, city ID: 2172880
# Processeing Record | jardim, city ID: 3460087
# Processeing Record | hobart, city ID: 2163355
# Processeing Record | benesov, city ID: 3079508
# City not found. Skipping nguiu
# Processeing Record | tabou, city ID: 2281120
# Processeing Record | eyl, city ID: 60019
# Processeing Record | jamestown, city ID: 3370903
# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
index = high_humidity_indicies_list

clean_city_data =cities_clean.drop(labels=None, axis=0, index=index, columns=None, level=None, inplace=False, errors='raise')

clean_city_data
# Out:
#     Latitude  Longitude                  City Country Code   Temp  Temp Max  \
# 0   -28.6500   153.6167             byron bay           au  43.36     44.87
# 1   -21.4803   -56.1381                jardim           br  84.72     84.72
# 2   -42.8794   147.3294                hobart           au  47.07     48.92
# 3    49.7816    14.6870               benesov           cz  69.64     71.69
# 4        NaN        NaN                 nguiu           au    NaN       NaN
# 5     4.4230    -7.3528                 tabou           ci  78.96     78.96
# 6     7.9803    49.8164                   eyl           so  81.90     81.90
# 7   -15.9387    -5.7168             jamestown           sh  65.82     65.82
# 8        NaN        NaN             taolanaro           mg    NaN       NaN
# 9        NaN        NaN             taolanaro           mg    NaN       NaN
# 10   37.7167   -25.4333  vila franca do campo           pt  72.01     72.01
# 11  -21.2078  -159.7750                avarua           ck  73.45     73.45
# 12   64.3833  -173.3000           provideniya           ru  41.83     41.83
# 13  -33.9258    18.4232             cape town           za  49.66     53.10
# 14       NaN        NaN           nizhneyansk           ru    NaN       NaN
# 15   65.6145   -37.6368              tasiilaq           gl  44.76     44.76
# 16   48.9370    34.4786           tsarychanka           ua  72.23     72.23
# 17   38.5167   -28.7000        ribeira grande           pt  73.80     73.80
# 18   15.7432   -96.4661              pochutla           mx  92.82     92.82
# 19       NaN        NaN          attawapiskat           ca    NaN       NaN
# 20   64.3833  -173.3000           provideniya           ru  41.83     41.83
# 21  -34.4187    19.2345              hermanus           za  44.80     47.89
# 22  -20.4081    57.7000             mahebourg           mu  71.26     71.26
# 23  -35.2613   174.1236               russell           nz  57.24     57.24
# 24       NaN        NaN               amderma           ru    NaN       NaN
# 25   66.7131    27.4306             kemijarvi           fi  51.69     51.69
# 26  -21.3585    55.7679        saint-philippe           re  68.34     69.39
# 27       NaN        NaN             taolanaro           mg    NaN       NaN
# 28       NaN        NaN            codrington           ag    NaN       NaN
# 29  -20.3428    57.7575       bambous virieux           mu  71.22     71.22
# 30   49.6668  -103.8511               weyburn           ca  81.72     81.72
# 31   47.6666   -52.7314                torbay           ca  56.73     60.76
# 32   71.0357    27.8492                mehamn           no  44.55     46.58
# 33   65.4167   -52.9000             maniitsoq           gl  45.19     45.19
# 34   69.4541  -133.0374           tuktoyaktuk           ca  60.78     60.78
# 35   63.7506   -68.5145               iqaluit           ca  41.70     42.53
# 36       NaN        NaN               vaitupu           wf    NaN       NaN
# 37   69.4865    88.3972               talnakh           ru  56.70     56.70
# 38       NaN        NaN          grand centre           ca    NaN       NaN
# 39   -9.8000  -139.0333                atuona           pf  77.68     77.68
# 40   46.4856   135.8833                vostok           ru  66.81     66.81
# 41  -34.0033    24.7314          kruisfontein           za  45.88     45.88
# 42   -3.6667   152.4333             namatanai           pg  78.30     78.30
# 43   77.4840   -69.3632               qaanaaq           gl  37.13     37.13
# 44  -14.4086   -56.4461            diamantino           br  92.95     92.95
# 41     45.88   986717.0       28.27      79.0        79.0  07/21/2021
# 42     78.30  2090021.0        4.88      86.0       100.0  07/21/2021
# 43     37.13  3831208.0       12.80      99.0       100.0  07/21/2021
# 44     92.95  3464724.0        5.41      15.0         2.0  07/21/2021
# 46       NaN        NaN         NaN       NaN         NaN  07/21/2021
# 47     82.51  2964782.0        7.94      64.0       100.0  07/21/2021
# 48     53.44  2071860.0       25.64      74.0        87.0  07/21/2021
# 49     65.82  3370903.0       20.49      77.0        91.0  07/21/2021

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
graph_date = clean_city_data["Date"][1]

Lat_Max_Temp = clean_city_data.plot.scatter(x = "Latitude", y = "Temp Max", 
                                            title = "City Latitude vs. Max Temperature " +str(graph_date))

plt.ylabel("Max Temperature (F)")
# Out:
# Text(0, 0.5, 'Max Temperature (F)')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
graph_date = clean_city_data["Date"][1]

Lat_Humidity = clean_city_data.plot.scatter(x = "Latitude", y = "Humidity",
                                            title = "City Latitude vs. Humidity " +str(graph_date))

plt.ylabel("Humidity (%)")
# Out:
# Text(0, 0.5, 'Humidity (%)')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
graph_date = clean_city_data["Date"][1]

Lat_Cloudiness = clean_city_data.plot.scatter(x = "Latitude", y = "Cloudiness", 
                                            title = "City Latitude vs. Cloudiness " +str(graph_date))

plt.ylabel("Cloudiness (%)")
# Out:
# Text(0, 0.5, 'Cloudiness (%)')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
graph_date = clean_city_data["Date"][1]

Lat_Wind_Speed = clean_city_data.plot.scatter(x = "Latitude", y = "Wind Speed", 
                                            title = "City Latitude vs. Wind Speed " +str(graph_date))

plt.ylabel("Wind Speed (mph)")
# Out:
# Text(0, 0.5, 'Wind Speed (mph)')

# %% [markdown]
# ## Linear Regression

# %%
NHem = cities_clean[cities_clean['Latitude'] > 0]
SHem = cities_clean[cities_clean['Latitude'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
graph_date = cities_clean["Date"][1]

NHem_Lat_Max_Temp = NHem.plot.scatter(x = "Latitude", y = "Temp Max", 
                                            title = "Northern Hemisphere \nCity Latitude vs. Max Temperature " +str(graph_date))

plt.ylabel("Max Temperature (F)")

slope, intercept, rvalue, pvalue, stderr = stats.linregress(NHem["Latitude"], 
                                                            NHem["Temp Max"])

regress_values = NHem["Latitude"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(NHem["Latitude"],regress_values,"r-")
plt.annotate(line_eq,(10,40),fontsize=12,color="red")
plt.grid(True)
print(f"The r-value is: {rvalue**2}")
print
plt.show()
# Out:
# The r-value is: 0.6423488831317438

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
graph_date = cities_clean["Date"][1]

SHem_Lat_Max_Temp = SHem.plot.scatter(x = "Latitude", y = "Temp Max", 
                                            title = "Southern Hemisphere \nCity Latitude vs. Max Temperature " +str(graph_date))

plt.ylabel("Max Temperature (F)")

slope, intercept, rvalue, pvalue, stderr = stats.linregress(SHem["Latitude"], 
                                                            SHem["Temp Max"])

regress_values = SHem["Latitude"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(SHem["Latitude"],regress_values,"r-")
plt.annotate(line_eq,(-20,45),fontsize=12,color="red")
plt.grid(True)
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.6428016933594712

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
graph_date = cities_clean["Date"][1]

NHem_Lat_Max_Temp = NHem.plot.scatter(x = "Latitude", y = "Humidity", 
                                            title = "Northern Hemisphere \nCity Latitude vs. Humidity " +str(graph_date))

plt.ylabel("Humidity (%)")

slope, intercept, rvalue, pvalue, stderr = stats.linregress(NHem["Latitude"], 
                                                            NHem["Humidity"])

regress_values = NHem["Latitude"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(NHem["Latitude"],regress_values,"r-")
plt.annotate(line_eq,(30,50),fontsize=12,color="red")
plt.grid(True)
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.1387566585988129

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
graph_date = cities_clean["Date"][1]

SHem.plot.scatter(x = "Latitude", y = "Humidity", 
                                            title = "Southern Hemisphere \nCity Latitude vs. Humidity " +str(graph_date))

plt.ylabel("Humidity (%)")

slope, intercept, rvalue, pvalue, stderr = stats.linregress(SHem["Latitude"], 
                                                            SHem["Humidity"])

regress_values = SHem["Latitude"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(SHem["Latitude"],regress_values,"r-")
plt.annotate(line_eq,(-40,20),fontsize=12,color="red")
plt.grid(True)
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.0731254271450258

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
graph_date = cities_clean["Date"][1]

NHem.plot.scatter(x = "Latitude", y = "Humidity", 
                                            title = "Northern Hemisphere \nCity Latitude vs. Cloudiness " +str(graph_date))

plt.ylabel("Cloudiness (%)")

slope, intercept, rvalue, pvalue, stderr = stats.linregress(NHem["Latitude"], 
                                                            NHem["Cloudiness"])

regress_values = NHem["Latitude"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(NHem["Latitude"],regress_values,"r-")
plt.annotate(line_eq,(30,50),fontsize=12,color="red")
plt.grid(True)
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.007191736124920965

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
graph_date = cities_clean["Date"][1]

SHem.plot.scatter(x = "Latitude", y = "Humidity", 
                                            title = "Southern Hemisphere \nCity Latitude vs. Cloudiness " +str(graph_date))

plt.ylabel("Cloudiness (%)")

slope, intercept, rvalue, pvalue, stderr = stats.linregress(SHem["Latitude"], 
                                                            SHem["Cloudiness"])

regress_values = SHem["Latitude"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(SHem["Latitude"],regress_values,"r-")
plt.annotate(line_eq,(-40,20),fontsize=12,color="red")
plt.grid(True)
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.0002270764673154326

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
graph_date = cities_clean["Date"][1]

NHem.plot.scatter(x = "Latitude", y = "Wind Speed", 
                                            title = "Northern Hemisphere \nCity Latitude vs. Wind Speed " +str(graph_date))

plt.ylabel("Wind Speed (mph)")

slope, intercept, rvalue, pvalue, stderr = stats.linregress(NHem["Latitude"], 
                                                            NHem["Wind Speed"])

regress_values = NHem["Latitude"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(NHem["Latitude"],regress_values,"r-")
plt.annotate(line_eq,(10,3),fontsize=12,color="red")
plt.grid(True)
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.02746726904377087

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
graph_date = cities_clean["Date"][1]

SHem.plot.scatter(x = "Latitude", y = "Wind Speed", 
                                            title = "Southern Hemisphere \nCity Latitude vs. Wind Speed " +str(graph_date))

plt.ylabel("Wind Speed (mph)")

slope, intercept, rvalue, pvalue, stderr = stats.linregress(SHem["Latitude"], 
                                                            SHem["Wind Speed"])

regress_values = SHem["Latitude"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(SHem["Latitude"],regress_values,"r-")
plt.annotate(line_eq,(-30,1),fontsize=12,color="red")
plt.grid(True)
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.0030951640944599456
